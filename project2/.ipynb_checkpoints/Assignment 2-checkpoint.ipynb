# %%
import sqlite3
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns

# %%
# Provided test function
sqlite_file = 'lahman2014.sqlite'
conn = sqlite3.connect(sqlite_file)

salary_query = "SELECT yearID, sum(salary) as total_payroll FROM Salaries WHERE lgID == 'AL' GROUP BY yearID"

team_salaries = pd.read_sql(salary_query, conn)
team_salaries.head()
# Out:
#    yearID  total_payroll
# 0    1985    134401120.0
# 1    1986    157716444.0
# 2    1987    136088747.0
# 3    1988    157049812.0
# 4    1989    188771688.0

# %% [markdown]
# ## Part 1: Wrangling

# %% [markdown]
# #### Problem 1

# %%
# TODO Look for missing data before describing what I do with it
# By doing an inner join, I remove all the team/year combinations which don't have a team ID

query = """
WITH Payrolls AS (
    SELECT teamID, yearID, sum(salary) as totalPayroll 
    FROM Salaries 
    GROUP BY teamID, yearID
)
SELECT yearID, teamID, franchID, totalPayroll, G, W, CAST(W as REAL) / G * 100 as winPercentage
FROM Payrolls NATURAL INNER JOIN Teams
"""
team_payrolls = pd.read_sql(query, conn)
team_payrolls.head()
# Out:
#    yearID teamID franchID  totalPayroll    G   W  winPercentage
# 0    1985    ATL      ATL    14807000.0  162  66      40.740741
# 1    1985    BAL      BAL    11560712.0  161  83      51.552795
# 2    1985    BOS      BOS    10897560.0  163  81      49.693252
# 3    1985    CAL      ANA    14427894.0  162  90      55.555556
# 4    1985    CHA      CHW     9846178.0  163  85      52.147239

# %% [markdown]
# ## Part 2: Exploratory Data Analysis

# %% [markdown]
# #### Problem 2

# %%
payrolls_range = team_payrolls[team_payrolls["yearID"] >= 1990].copy()
print(payrolls_range)
# Out:
#      yearID teamID franchID  totalPayroll    G   W  winPercentage
# 130    1990    ATL      ATL    14555501.0  162  65      40.123457
# 131    1990    BAL      BAL     9680084.0  161  76      47.204969
# 132    1990    BOS      BOS    20558333.0  162  88      54.320988
# 133    1990    CAL      ANA    21720000.0  162  80      49.382716
# 134    1990    CHA      CHW     9491500.0  162  94      58.024691
# ..      ...    ...      ...           ...  ...  ..            ...
# 853    2014    SLN      STL   120693000.0  162  90      55.555556
# 854    2014    TBA      TBD    72689100.0  162  77      47.530864
# 855    2014    TEX      TEX   112255059.0  162  67      41.358025
# 856    2014    TOR      TOR   109920100.0  162  83      51.234568
# 857    2014    WAS      WSN   131983680.0  162  96      59.259259
#
# [728 rows x 7 columns]

# %%
sns.lineplot(x="yearID", y="totalPayroll", data=payrolls_range, hue="teamID")
plt.legend(bbox_to_anchor=[1,1], ncol=3)

# %%
#plt.hist(payrolls_range.totalPayroll)

# %%
#plt.hist(np.log10(payrolls_range.totalPayroll))

# %% [markdown]
# #### Question 1

# %% [markdown]
# The mean payroll for the teams has clearly increased over time, and the spread of the teams payrolls has increased as well.

# %% [markdown]
# #### Problem 3

# %%
# Show the mean value of payroll over year with 95 percent confidence interval
sns.lineplot(x="yearID", y="totalPayroll", data=payrolls_range)
plt.legend(bbox_to_anchor=[1,1], ncol=3)
# Out:
# No handles with labels found to put in legend.

# %%
# Show standard deviation of payroll over time
payrolls_by_year = payrolls_range.groupby("yearID")
payrolls_range_years = payrolls_by_year.groups.keys()
plt.plot(payrolls_range_years,payrolls_by_year.std().totalPayroll)

# %% [markdown]
# #### Problem 4

# %%
# Split the data into bins of 5 years each
payrolls_bins = np.array_split(list(range(1990,2015)), 5)
payrolls_binned = [payrolls_range[payrolls_range.yearID.isin(x)] for x in payrolls_bins]
# Plot mean payroll over time
# TODO label axes
sns.barplot(x=["1990-1994", "1995-1999", "2000-2004", "2005-2009", "2010-2014"],\
         y=[np.mean(x.totalPayroll) for x in payrolls_binned])
# Out:
# <AxesSubplot:>

# %%
for x in payrolls_binned:
    sns.scatterplot(x=x.totalPayroll,y=x.winPercentage)

# %%
"""
plt.figure(figsize=(6*len(payrolls_binned), 6*2))
for i in range(len(payrolls_binned)):
    # Put 5-year plots next to each other horizontally
    plt.subplot(2, len(payrolls_binned), i+1)
    # Plot points
    x = payrolls_binned[i].totalPayroll
    y = payrolls_binned[i].winPercentage
    labels = payrolls_binned[i].teamID
    labels = labels[~labels.isnull()]
    
    sns.scatterplot(x=x, y=y)
    # Add team labels
    for (label, xval, yval) in zip(labels, x, y):
        plt.annotate(label, (xval, yval))
    
    # Repeat process to show colors as well
    plt.subplot(2, len(payrolls_binned), len(payrolls_binned)+i+1)
    sns.scatterplot(x=x, y=y, hue=labels)
    plt.legend([],[], frameon=False)
    # Plot line of best fit
    m, b = np.polyfit(x, y, 1)
    plt.plot(x, m*x+b)
"""
# Out:
# '\nplt.figure(figsize=(6*len(payrolls_binned), 6*2))\nfor i in range(len(payrolls_binned)):\n    # Put 5-year plots next to each other horizontally\n    plt.subplot(2, len(payrolls_binned), i+1)\n    # Plot points\n    x = payrolls_binned[i].totalPayroll\n    y = payrolls_binned[i].winPercentage\n    labels = payrolls_binned[i].teamID\n    labels = labels[~labels.isnull()]\n    \n    sns.scatterplot(x=x, y=y)\n    # Add team labels\n    for (label, xval, yval) in zip(labels, x, y):\n        plt.annotate(label, (xval, yval))\n    \n    # Repeat process to show colors as well\n    plt.subplot(2, len(payrolls_binned), len(payrolls_binned)+i+1)\n    sns.scatterplot(x=x, y=y, hue=labels)\n    plt.legend([],[], frameon=False)\n    # Plot line of best fit\n    m, b = np.polyfit(x, y, 1)\n    plt.plot(x, m*x+b)\n'

# %%
plt.figure(figsize=(12, 7*len(payrolls_binned)))
for i in range(len(payrolls_binned)):
    plt.subplot(len(payrolls_binned), 1, i+1)
    # Get aggregate wins, salary for each team
    dfg = payrolls_binned[i].groupby("teamID").agg(["sum","mean"]).reset_index()
    x = dfg["totalPayroll"]["mean"]
    y = dfg.apply(lambda e: e["W"]["sum"] / e["G"]["sum"] * 100, axis=1)
    
    [print(x) for x in list(zip(dfg["teamID"], y, \
        dfg["winPercentage"]["mean"], dfg["totalPayroll"]["mean"]))]
    
    dfg["avgTotalPayroll"] = x
    dfg["avgWinPercentage"] = y
    sns.scatterplot(x="avgTotalPayroll", y="avgWinPercentage", hue="teamID", \
                    data=dfg, legend=False)
    
    # Add labels
    plt.title(f"Average Total Payrolls vs Average Win Percentage From {1990+i*5} to {1990+(i+1)*5-1}")
    plt.xlabel("Average Total Payrolls (tens of millions of dollars)")
    plt.ylabel("Average Win Percentage (%)")
        
    # Add team labels
    for (label, xval, yval) in zip(dfg["teamID"], x, y):
        plt.annotate(label, (xval, yval))
    
    # Plot line of best fit
    p = np.poly1d(np.polyfit(x, y, 1))
    plt.plot([min(x),max(x)], [p(min(x)), p(max(x))])
# Out:
# ('ATL', 56.2992125984252, 56.497725795971405, 31721852.8)
# ('BAL', 50.06587615283268, 50.44408020857296, 23785204.0)
# ('BOS', 49.67234600262123, 49.51476113794954, 34863216.8)
# ('CAL', 46.00262123197903, 45.704777241009126, 28654777.4)
# ('CHA', 56.24178712220762, 56.42630831421393, 27090400.4)
# ('CHN', 48.026315789473685, 47.74011730707489, 28460670.4)
# ('CIN', 51.63826998689384, 51.972088030059034, 32489666.2)
# ('CLE', 46.254927726675426, 46.99005790451218, 18109308.8)
# ('COL', 43.01075268817204, 43.32858499525166, 17120416.5)
# ('DET', 49.279161205766705, 49.093934514224365, 29670214.2)
# ('FLO', 41.51624548736462, 41.92699946323135, 20481772.5)
# ('HOU', 48.75491480996068, 49.256038647343, 21985300.0)
# ('KCA', 49.4750656167979, 49.829921018326814, 33092450.6)
# ('LAN', 50.0, 50.05198180636777, 35245906.8)
# ('MIN', 50.32851511169514, 50.121271714192076, 24529620.0)
# ('ML4', 48.62385321100918, 48.47665056360709, 24401133.6)
# ('MON', 53.937007874015755, 54.57064214927129, 16227677.6)
# ('NYA', 48.88304862023653, 49.6733311482574, 34831210.8)
# ('NYN', 46.578947368421055, 46.70713807304803, 33783017.4)
# ('OAK', 52.75590551181102, 52.28070175438596, 33981300.2)
# ('PHI', 49.279161205766705, 49.14439076757917, 24036433.4)
# ('PIT', 54.7244094488189, 54.23651721897336, 24434910.2)
# ('SDN', 45.62091503267974, 45.31813865147198, 21404033.6)
# ('SEA', 46.71052631578947, 46.527777777777786, 22670033.2)
# ('SFN', 51.11402359108781, 50.92324208266238, 32230966.6)
# ('SLN', 49.41022280471822, 49.21739130434783, 24522021.2)
# ('TEX', 50.26246719160105, 49.98700454840805, 26515519.0)
# ('TOR', 55.43905635648755, 54.99731615673645, 34632150.2)
# ('ANA', 49.17695473251029, 49.17695473251029, 42601546.0)
# ('ARI', 50.92592592592593, 50.925925925925924, 50525499.5)
# ('ATL', 62.62626262626263, 62.62345679012346, 56707689.0)
# ('BAL', 52.20680958385876, 52.140138604862535, 61982146.6)
# ('BOS', 54.92424242424242, 55.03086419753087, 47732453.6)
# ('CAL', 48.36601307189542, 48.63568215892054, 29980585.5)
# ('CHA', 48.9281210592686, 48.886235883583836, 42759156.4)
# ('CHN', 47.16267339218159, 47.23121639021434, 43584633.4)
# ('CIN', 52.33291298865069, 52.473585548738924, 38481353.0)
# ('CLE', 59.62025316455696, 59.833218311479186, 55325256.6)
# 2   409     5    252.469136     5           -1.241078     5  0.504938
# 3   416     5    256.790123     5            7.509964     5  0.513580
# 4   388     5    239.506173     5            1.217092     5  0.479012
# 5   346     5    213.580247     5            1.234665     5  0.427160
# 6   433     5    267.283951     5           -1.041257     5  0.534568
# 7   394     5    243.209877     5           -3.284116     5  0.486420
# 8   360     5    222.222222     5           -1.463138     5  0.444444
# 9   447     5    275.925926     5            4.176524     5  0.551852
# 10  152     2     93.827160     2           -1.762679     2  0.469136
# 11  308     5    190.123457     5           -4.627146     5  0.380247
# 12  385     5    237.654321     5           -3.889180     5  0.475309
# 13  431     5    266.049383     5            3.992070     5  0.532099
# 14  434     5    268.215628     5            5.396895     5  0.536465
# 15  208     3    128.395062     3           -2.099631     3  0.427984
# 16  412     5    254.320988     5           -0.898811     5  0.508642
# 17  359     5    221.604938     5           -0.311548     5  0.443210
# 18  456     5    281.481481     5           13.215849     5  0.562963
# 19  383     5    236.419753     5           -0.904582     5  0.472840
# 20  433     5    267.283951     5           -4.164766     5  0.534568
# 21  426     5    262.962963     5            8.575864     5  0.525926
# 22  390     5    240.740741     5           -4.567302     5  0.481481
# 23  390     5    240.740741     5           -4.949235     5  0.481481
# 24  361     5    222.839506     5           -1.418125     5  0.445679
# 25  436     5    269.135802     5            0.422749     5  0.538272
# 26  451     5    278.395062     5            0.999086     5  0.556790
# 27  446     5    274.960236     5           -4.253640     5  0.549938
# 28  437     5    269.408468     5            0.180322     5  0.538841
# 29  396     5    244.444444     5           -1.370011     5  0.488889
# 30  429     5    265.121540     5           -0.976511     5  0.530284
#
#               y
#
# 0    75231266.4
# 1    87947365.0
# 2    86415974.0
# 3   157589270.8
# 4   106426855.4
# 5   105188717.6
# 6    88906850.8
# 7    69266906.2
# 8    84051442.6
# 9   131942031.8
# 10   56986859.5
# 11   55341500.0
# 12   64543847.0
# 13  128831039.6
# 14  147013477.2
# 15   64505600.0
# 16   88484717.6
# 17   92696233.2
# 18  206930699.8
# 19   85364516.0
# 20   61940960.0
# 21  168050370.4
# 22   59436399.8
# 23   56036868.0
# 24   84226968.6
# 25   98928136.6
# 26  104445659.0
# 27   60558982.8
# 28   98567688.2
# 29   87203840.0
# 30   90359804.2

# %% [markdown]
# #### Question 2

# %% [markdown]
# In each interval, there is a broadly positive correlation between the total payroll and the win percentage of a team, though the correlation appears quite weak. In particular, the correlation in the interval from 1990 to 1994 appears close to zero. In this interval, MON (
#
#
#
# There are a few outliers above the line of best fit (i.e. teams that had a higher win percentage than would be predicted from their total payroll), but based on visual analysis, the only team that *consistently* was ahead in this respect were the Oakland Athletics from 2000 to 2004. While they spent less than 5 dollars each year, their average win percentage was around 60 percent -- which is what we would predict for a team spending nearly 15 million dollars per year.
# If we look at the cost divided by win percentage for each team over these 5 years:

# %%
query = """
WITH Payrolls AS (
    SELECT teamID, yearID, sum(salary) as totalPayroll 
    FROM Salaries 
    GROUP BY teamID, yearID
)
SELECT teamID, avg(totalPayroll / (CAST(W as REAL) / G * 100)) as costPerWinPercent
FROM Payrolls NATURAL INNER JOIN Teams
WHERE 2000 < yearID AND yearID < 2004
GROUP BY teamID
"""
payrolls_efficiency_2000_2004 = pd.read_sql(query, conn)
payrolls_efficiency_2000_2004.sort_values("costPerWinPercent").head()
# Out:
#    teamID  costPerWinPercent
# 20    OAK      671445.863757
# 16    MIN      717121.683354
# 11    FLO      834492.865516
# 17    MON      868777.191708
# 13    KCA      969483.540913

# %% [markdown]
# We can see from the above data that the Oakland Athletics spent significantly less relative to their win percentage than any other team. Furthermore, if we make a violin plot for each of the teams's "payroll efficiency" in this interval:

# %%
plt.figure(figsize=(30, 6))
payrolls_2000_2004 = payrolls_binned[2]
# Add new column for total payroll divided by win percentage
# Ignore the warning, since it works well enough in this case
payrolls_2000_2004["costPerWinPercent"] = \
    payrolls_2000_2004.totalPayroll / payrolls_2000_2004.winPercentage
# Plot 'cost per win percentage' for each team in this interval
sns.violinplot(x="teamID", y="costPerWinPercent", data=payrolls_2000_2004)
# Out:
# <ipython-input-15-304a407b0c1c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   payrolls_2000_2004["costPerWinPercent"] = \
# <AxesSubplot:xlabel='teamID', ylabel='costPerWinPercent'>

# %% [markdown]
# The plot shows that the Oakland Athletics also were consistently efficient with their payroll, as shown by their low interquartile range.

# %% [markdown]
# ## Part 3: Data Transformations

# %% [markdown]
# #### Problem 5

# %%
# Standardize payroll cost over each year
payrolls_mean_std = payrolls_range.groupby("yearID")["totalPayroll"].agg(["mean", "std"])
payrolls_range["standardizedPayroll"] = \
    payrolls_range.apply( lambda x: \
        (x["totalPayroll"] - payrolls_mean_std["mean"][x["yearID"]]) / \
        payrolls_mean_std["std"][x["yearID"]], axis=1)

# Re-do the splitting for the payroll bins per 5 years
payrolls_bins = np.array_split(list(range(1990,2015)), 5)
payrolls_binned = [payrolls_range[payrolls_range.yearID.isin(x)] for x in payrolls_bins]
payrolls_binned
# Out:
# [     yearID teamID franchID  totalPayroll    G   W  winPercentage  \
#  130    1990    ATL      ATL    14555501.0  162  65      40.123457
#  131    1990    BAL      BAL     9680084.0  161  76      47.204969
#  132    1990    BOS      BOS    20558333.0  162  88      54.320988
#  133    1990    CAL      ANA    21720000.0  162  80      49.382716
#  134    1990    CHA      CHW     9491500.0  162  94      58.024691
#  ..      ...    ...      ...           ...  ...  ..            ...
#  259    1994    SEA      SEA    29228500.0  112  49      43.750000
#  260    1994    SFN      SFG    42638666.0  115  55      47.826087
#  261    1994    SLN      STL    29275601.0  115  53      46.086957
#  262    1994    TEX      TEX    32973597.0  114  52      45.614035
#  263    1994    TOR      TOR    43433668.0  115  55      47.826087
#
#       standardizedPayroll
#  130            -0.667275
#  131            -1.959861
#  132             0.924213
#  133             1.232198
#  134            -2.009859
#  ..                   ...
#  259            -0.458275
#  260             1.114074
#  261            -0.452752
#  262            -0.019160
#  263             1.207288
#
#  [134 rows x 8 columns],
#       yearID teamID franchID  totalPayroll    G   W  winPercentage  \
#  264    1995    ATL      ATL    47235445.0  144  90      62.500000
#  265    1995    BAL      BAL    43942521.0  144  71      49.305556
#  266    1995    BOS      BOS    32455518.0  144  86      59.722222
#  267    1995    CAL      ANA    31223171.0  145  78      53.793103
#  268    1995    CHA      CHW    46961282.0  145  68      46.896552
#  ..      ...    ...      ...           ...  ...  ..            ...
#  403    1999    SFN      SFG    46595057.0  162  86      53.086420
#  404    1999    SLN      STL    49778195.0  161  75      46.583851
#  405    1999    TBA      TBD    38870000.0  162  69      42.592593
#  406    1999    TEX      TEX    76709931.0  162  95      58.641975
#  407    1999    TOR      TOR    45444333.0  162  84      51.851852
#
#       standardizedPayroll
#  264             1.402879
#  265             1.054347
#  266            -0.161466
#  267            -0.291901
#  268             1.373861
#  ..                   ...
#  403            -0.156243
#  404            -0.001431
#  405            -0.531951
#  406             1.308393
#  407            -0.212209
#
#  [144 rows x 8 columns],
#       yearID teamID franchID  totalPayroll    G    W  winPercentage  \
#  408    2000    ANA      ANA    51464167.0  162   82      50.617284
#  409    2000    ARI      ARI    81027833.0  162   85      52.469136
#  410    2000    ATL      ATL    84537836.0  162   95      58.641975
#  411    2000    BAL      BAL    81447435.0  162   74      45.679012
#  412    2000    BOS      BOS    77940333.0  162   85      52.469136
#  ..      ...    ...      ...           ...  ...  ...            ...
#  553    2004    SFN      SFG    82019166.0  162   91      56.172840
#  554    2004    SLN      STL    83228333.0  162  105      64.814815
#  555    2004    TBA      TBD    29556667.0  161   70      43.478261
#  556    2004    TEX      TEX    55050417.0  162   89      54.938272
#  557    2004    TOR      TOR    50017000.0  161   67      41.614907
#
#       standardizedPayroll
#  408            -0.190214
#  409             1.190219
#  410             1.354114
#  411             1.209812
#  412             1.046053
#  ..                   ...
#  553             0.395958
#  554             0.432796
#  555            -1.202333
#  556            -0.425656
#  557            -0.579001
#
#  [150 rows x 8 columns],
#       yearID teamID franchID  totalPayroll    G   W  winPercentage  \
#  558    2005    ARI      ARI    62329166.0  162  77      47.530864
#  559    2005    ATL      ATL    86457302.0  162  90      55.555556
#  560    2005    BAL      BAL    73914333.0  162  74      45.679012
#  561    2005    BOS      BOS   123505125.0  162  95      58.641975
#  562    2005    CHA      CHW    75178000.0  162  99      61.111111
#  ..      ...    ...      ...           ...  ...  ..            ...
#  703    2009    SLN      STL    88528409.0  162  91      56.172840
#  704    2009    TBA      TBD    63313034.0  162  84      51.851852
#  705    2009    TEX      TEX    68178798.0  162  87      53.703704
#  706    2009    TOR      TOR    80538300.0  162  75      46.296296
#  707    2009    WAS      WSN    59928000.0  162  59      36.419753
#
#       standardizedPayroll
#  558            -0.310988
#  559             0.395034
#  560             0.028010
#  561             1.479103
#  562             0.064986
#  ..                   ...
#  703            -0.008737
#  704            -0.753496
#  705            -0.609782
#  706            -0.244733
#  707            -0.853477
#
#  [150 rows x 8 columns],
#       yearID teamID franchID  totalPayroll    G   W  winPercentage  \
#  708    2010    ARI      ARI    60718166.0  162  65      40.123457
#  709    2010    ATL      ATL    84423666.0  162  91      56.172840
#  710    2010    BAL      BAL    81612500.0  162  66      40.740741
#  711    2010    BOS      BOS   162447333.0  162  89      54.938272
#  712    2010    CHA      CHW   105530000.0  162  88      54.320988
#  ..      ...    ...      ...           ...  ...  ..            ...
#  853    2014    SLN      STL   120693000.0  162  90      55.555556
#  854    2014    TBA      TBD    72689100.0  162  77      47.530864
#  855    2014    TEX      TEX   112255059.0  162  67      41.358025
#  856    2014    TOR      TOR   109920100.0  162  83      51.234568
#  857    2014    WAS      WSN   131983680.0  162  96      59.259259
#
#       standardizedPayroll
#  708            -0.786929
#  709            -0.164983
#  710            -0.238738
#  711             1.882075
#  712             0.388771
#  ..                   ...
#  853             0.457126
#  854            -0.593171
#  855             0.272509
#  856             0.221422
#  857             0.704160
#
#  [150 rows x 8 columns]]

# %% [markdown]
# #### Problem 6

# %%
plt.figure(figsize=(12, 7*len(payrolls_binned)))
for i in range(len(payrolls_binned)):
    # Put 5-year plots on top of each other
    plt.subplot(len(payrolls_binned), 1, i+1)
    # Get aggregate wins, salary for each team
    # (This assumes that each team plays the same number of games per season)
    payrolls_per_team = payrolls_binned[i].groupby("teamID").mean().reset_index()
    sns.scatterplot(x="standardizedPayroll", y="winPercentage", hue="teamID", \
                    data=payrolls_per_team, legend=False)
    
    # Add labels
    plt.title(f"Average Standardized Payrolls vs Average Win Percentage From {1990+i*5} to {1990+(i+1)*5-1}")
    plt.xlabel("Average Standardized Payrolls")
    plt.ylabel("Average Win Percentage (%)")
    
    # Add team labels
    for (i, row) in payrolls_per_team.iterrows():
        plt.annotate(row.teamID, (row.standardizedPayroll, row.winPercentage))
    
    # Plot line of best fit
    x = payrolls_per_team["standardizedPayroll"]
    y = payrolls_per_team["winPercentage"]
    p = np.poly1d(np.polyfit(x, y, 1))
    plt.plot([min(x),max(x)], [p(min(x)), p(max(x))])

# %% [markdown]
# #### Question 3

# %% [markdown]
# Overall, the plots for Problem 6 appears very similar in shape to the plots generated for Problem 4, with a weak positive correlation between (standardized) payroll and win percentage. However, instead of the x axis showing values in the millions or tens of millions of dollars, it now shows the payroll amount standardized against the other payrolls within the year (in this case, roughly between -2.5 and 4). (I think the meaningfulness of this standardization assumes that payrolls are distributed normally within a year?)
# I would expect that points that represent values from earlier years would move to the right on the graph, since they are now being compared in relative terms, and previous years will have smaller average payrolls than more recent years. However, these slight changes don't meaningfully impact the takewayws from the plots.

# %% [markdown]
# #### Problem 7

# %%
plt.figure(figsize=(15, 30))
x = payrolls_range.standardizedPayroll
y = payrolls_range.winPercentage
labels = payrolls_range.teamID
labels = labels[~labels.isnull()]

# Plot data with team labels
plt.subplot(2,1,1)
sns.scatterplot(x=x, y=y)
# Add team labels
for (label, xval, yval) in zip(labels, x, y):
    plt.annotate(label, (xval, yval))
    
# Plot data with colors, trend line
plt.subplot(2,1,2)
sns.scatterplot(x=x, y=y, hue=labels)
plt.legend(loc='lower right', ncol=2)
# Plot line of best fit
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x+b)

# %%
# Calculate expected win percentage based on the formula given in the README
payrolls_range["expectedWinPercentage"] = 50 + 2.5 * payrolls_range["standardizedPayroll"]
payrolls_range.head()
# Out:
#      yearID teamID franchID  totalPayroll    G   W  winPercentage  \
# 130    1990    ATL      ATL    14555501.0  162  65      40.123457
# 131    1990    BAL      BAL     9680084.0  161  76      47.204969
# 132    1990    BOS      BOS    20558333.0  162  88      54.320988
# 133    1990    CAL      ANA    21720000.0  162  80      49.382716
# 134    1990    CHA      CHW     9491500.0  162  94      58.024691
#
#      standardizedPayroll  expectedWinPercentage
# 130            -0.667275              48.331811
# 131            -1.959861              45.100348
# 132             0.924213              52.310533
# 133             1.232198              53.080495
# 134            -2.009859              44.975353

# %% [markdown]
# #### Problem 8

# %%
# Record "efficiency" of each team
payrolls_range["efficiency"] = payrolls_range["winPercentage"] - payrolls_range["expectedWinPercentage"]
#payrolls_range.head()

# Make line plot of year versus efficiency for various teams
relevant_teams = ["OAK", "BOS", "NYA", "ATL", "TBA"]
payrolls_relevant_teams = payrolls_range[payrolls_range["teamID"].isin(relevant_teams)]
sns.lineplot(x="yearID", y="efficiency", hue="teamID", data=payrolls_relevant_teams)
# Out:
# <AxesSubplot:xlabel='yearID', ylabel='efficiency'>

# %% [markdown]
# #### Question 4

# %% [markdown]
# This graph allows us to track the efficiencies of individual teams over time, which was much harder to do when we were looking at all of the data point for all of the teams. This data is also plotted over time explicitly, so we can see how teams changed over the years and compare them year to year.
# We can see from this plot that the Oakland Athletics' incredible efficiency only lasted for a few years, jumping dramatically in the late 90's and descending back to the average in the mid to late 00's. But in that window of a few years, the Athletics had maximum efficiency over **15**. In other words, their win percentage was over 15% higher than our linear regression predicts, or 15% more than what we would expect if they were average for their payroll class.

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# In order to get the most recent data, all you need to do is run the following code, which will create a databse file `lehman2020.db` with all of the 2020 data from Lehman's archive. No human intervention is needed.

# %%
import requests, zipfile, os

# %%
file_url = "https://github.com/chadwickbureau/baseballdatabank/archive/master.zip"
zip_path = "master.zip"
db_name = "lehman2020.db"
csv_path = "./baseballdatabank-master/core"

# %%
# Download the data as comma-separated values in a ZIP from Lehman's website
# (Which I found just by doing a web search) 
r = requests.get(file_url)
with open(zip_path, 'wb') as fd:
    for chunk in r.iter_content(chunk_size=128):
        fd.write(chunk)

# %%
# Open and extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(".")

# %%
# Create new database
connection = sqlite3.connect(db_name)

# For every file in the directory...
for filename in os.listdir(csv_path):
    # Get the parts of the file name -- if it's a CSV...
    file_parts = os.path.splitext(filename)
    # If it's a CSV...
    if file_parts[1] == ".csv":
        # Read in CSV into Pandas dataframe
        df = pd.DataFrame(pd.read_csv(csv_path + "/" + filename))  
        # Create a new table with the same name as the file
        # Note: I'm not using prepared statements because who cares
        #cursor = connection.cursor()
        df.to_sql(file_parts[0], connection, if_exists="replace")

# %%
# Testing out the new database
team_salaries = pd.read_sql(salary_query, connection)
team_salaries.head()
# Out:
#    yearID  total_payroll
# 0    1985      134401120
# 1    1986      157716444
# 2    1987      136088747
# 3    1988      157049812
# 4    1989      188771688
